# %% [markdown]
# <a href="https://colab.research.google.com/github/yybbyyya-329/physics-/blob/20250402/20250402.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
# 사용자 입력

t = float(input("공이 떨어지기까지 걸린 시간 (초)을 입력하세요 : "));

x = float(input("수평 거리 (m)를 입력하세요 : "));
# Out:
# 공이 떨어지기까지 걸린 시간 (초)을 입력하세요 : 2
# 수평 거리 (m)를 입력하세요 : 20

# %%
# 중력 가속도

g = -9.81  # m/s^2

# %%
# a) 공의 처음속도 (수평속도)

v0 = x /t

# %%
# b) 옥상의 높이 (자유낙하 공식 사용)

y = abs(g * t**2)/2

# %%
# c) 공이 지면에 닿을 때 속도

vx = v0

vy = g * t

# %%
# 최종 속도 크기

v = math.sqrt(vx*vx+vy*vy)

# %%
# 최종 속도 방향 (아래로 향한 각도, 단위: 도)

theta_rad = math.atan(vy/vx)

theta_deg =math.degrees(theta_rad)

# 결과 출력

print(f"\n[결과]")

print(f"a) 공의 처음속도 크기: {v0:.2f} m/s")

print(f"b) 건물 높이: {y:.2f} m")

print(f"c) 충돌 순간 속도 크기: {v:.2f} m/s")

print(f"   충돌 순간 속도 방향 (수평선과 이루는 각도): {theta_deg:.2f}도")
# Out:
# [결과]
# a) 공의 처음속도 크기: 10.00 m/s
# b) 건물 높이: 19.62 m
# c) 충돌 순간 속도 크기: 22.02 m/s
#    충돌 순간 속도 방향 (수평선과 이루는 각도): -62.99도
